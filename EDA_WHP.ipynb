# %% [markdown]
# # EDA on world happiness report 2021

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn 
import plotly.graph_objs as go
import plotly.express as px
from sklearn.ensemble import ExtraTreesClassifier     
from sklearn.feature_selection import SelectFromModel
# Out:
# C:\Temp\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Temp\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Temp\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %% [markdown]
# ### Reading the dataset and customizing according to the needs

# %% [raw]
# Here I haved dropped the columns of the imaginary land called dystopia(taken for refenrence). I would be focusing on the real world data. I have changed columns name to make it easy to understand.
#
# Changed column names:-
# Country name:- Country
# Regional indicator:- Region
# Ladder score:- Score
# Logged GDP per capita:- GDP(log)
# Freedom to make life choices:- Freedom
# Perceptions of corruption:- Corruption
# Healthy life expectancy:- Health
# Social support:- Support

# %%
df = pd.read_csv('report.csv')
df = df.iloc[:,0:12]
df = df.drop(columns=['Standard error of ladder score','upperwhisker','lowerwhisker'],axis=1)
df = df.rename(columns = {'Country name':'Country',
                          'Regional indicator': 'Region', 
                          'Ladder score': 'Score',
                          'Logged GDP per capita':'GDP(log)',
                          'Freedom to make life choices':'Freedom',
                          'Perceptions of corruption':'Corruption',
                          'Healthy life expectancy':'Health',
                          'Social support':'Support'})
df.head()
# Out:
#        Country          Region  Score  GDP(log)  Support  Health  Freedom  \
# 0      Finland  Western Europe  7.842    10.775    0.954    72.0    0.949
# 1      Denmark  Western Europe  7.620    10.933    0.954    72.7    0.946
# 2  Switzerland  Western Europe  7.571    11.117    0.942    74.4    0.919
# 3      Iceland  Western Europe  7.554    10.878    0.983    73.0    0.955
# 4  Netherlands  Western Europe  7.464    10.932    0.942    72.4    0.913
#
#    Generosity  Corruption
# 0      -0.098       0.186
# 1       0.030       0.179
# 2       0.025       0.292
# 3       0.160       0.673
# 4       0.175       0.338

# %%
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns in our data")
# Out:
# There are 149 rows and 9 columns in our data

# %%
#Checking if there are any null values
df.isnull().sum()
# Out:
# Country       0
# Region        0
# Score         0
# GDP(log)      0
# Support       0
# Health        0
# Freedom       0
# Generosity    0
# Corruption    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     149 non-null    object
#  1   Region      149 non-null    object
#  2   Score       149 non-null    float64
#  3   GDP(log)    149 non-null    float64
#  4   Support     149 non-null    float64
#  5   Health      149 non-null    float64
#  6   Freedom     149 non-null    float64
#  7   Generosity  149 non-null    float64
#  8   Corruption  149 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 10.6+ KB

# %%
df.describe()
# Out:
#             Score    GDP(log)     Support      Health     Freedom  Generosity  \
# count  149.000000  149.000000  149.000000  149.000000  149.000000  149.000000
# mean     5.532839    9.432208    0.814745   64.992799    0.791597   -0.015134
# std      1.073924    1.158601    0.114889    6.762043    0.113332    0.150657
# min      2.523000    6.635000    0.463000   48.478000    0.382000   -0.288000
# 25%      4.852000    8.541000    0.750000   59.802000    0.718000   -0.126000
# 50%      5.534000    9.569000    0.832000   66.603000    0.804000   -0.036000
# 75%      6.255000   10.421000    0.905000   69.600000    0.877000    0.079000
# max      7.842000   11.647000    0.983000   76.953000    0.970000    0.542000
#
#        Corruption
# count  149.000000
# mean     0.727450
# std      0.179226
# min      0.082000
# 25%      0.667000
# 50%      0.781000
# 75%      0.845000
# max      0.939000

# %% [markdown]
# ### Plotting correlation matrix

# %%
fig, ax = plt.subplots(figsize=(10,10))
sbn.heatmap(df.corr(), cmap="YlGnBu", annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Checking how many unique regions are there

# %%
print('Regions:')
for i in df['Region'].unique():
    print(i)
print('\nNumber of regions:',df['Region'].nunique())
# Out:
# Regions:
# Western Europe
# North America and ANZ
# Middle East and North Africa
# Latin America and Caribbean
# Central and Eastern Europe
# East Asia
# Southeast Asia
# Commonwealth of Independent States
# Sub-Saharan Africa
# South Asia
#
# Number of regions: 10

# %% [markdown]
# ### How many number of countries are there in a region

# %%
df.groupby('Region')[['Country']].nunique()
# Out:
#                                     Country
# Region
# Central and Eastern Europe               17
# Commonwealth of Independent States       12
# East Asia                                 6
# Latin America and Caribbean              20
# Middle East and North Africa             17
# North America and ANZ                     4
# South Asia                                7
# Southeast Asia                            9
# Sub-Saharan Africa                       36
# Western Europe                           21

# %% [markdown]
# ### Checking distribution of different columns

# %%
fig, ax = plt.subplots(3,3,figsize=(20,20))

sbn.histplot(df.Score,kde=True,ax=ax[0,0])
ax[0,0].set_title('Score')

sbn.histplot(df['GDP(log)'],kde=True,ax=ax[0,1])
ax[0,1].set_title('GDP')

sbn.histplot(df.Support,kde=True,ax=ax[0,2])
ax[0,2].set_title('Support')

sbn.histplot(df.Health,kde=True,ax=ax[1,0])
ax[1,0].set_title('Health')

sbn.histplot(df.Freedom,kde=True,ax=ax[1,1])
ax[1,1].set_title('Freedom')

sbn.histplot(df.Generosity,kde=True,ax=ax[1,2])
ax[1,2].set_title('Generosity')

sbn.histplot(df.Corruption,kde=True,ax=ax[2,0])
ax[2,0].set_title('Corruption')

fig.delaxes(ax[2,1])
fig.delaxes(ax[2,2])

# %% [markdown]
# ### Checking score for any country

# %%
def score(Country_name):
    for i in range(len(df['Country'])):
        if df['Country'].iloc[i] == Country_name:
            print(df['Score'][i])

name = input('Give the country name you want to get the score of: ')
score(name)
# Out:
# Give the country name you want to get the score of: India
# 3.819

# %% [markdown]
# ### Getting the top 5 and bottom 5 countries based on their Happiness score i.e. Score

# %%
# Top 5

top = df.sort_values(by='Score',ascending=False)
top.head()
# Out:
#        Country          Region  Score  GDP(log)  Support  Health  Freedom  \
# 0      Finland  Western Europe  7.842    10.775    0.954    72.0    0.949
# 1      Denmark  Western Europe  7.620    10.933    0.954    72.7    0.946
# 2  Switzerland  Western Europe  7.571    11.117    0.942    74.4    0.919
# 3      Iceland  Western Europe  7.554    10.878    0.983    73.0    0.955
# 4  Netherlands  Western Europe  7.464    10.932    0.942    72.4    0.913
#
#    Generosity  Corruption
# 0      -0.098       0.186
# 1       0.030       0.179
# 2       0.025       0.292
# 3       0.160       0.673
# 4       0.175       0.338

# %%
# Bottom 5
bottom = df.sort_values(by='Score',ascending=False)
bottom.tail()
# Out:
#          Country              Region  Score  GDP(log)  Support  Health  \
# 144      Lesotho  Sub-Saharan Africa  3.512     7.926    0.787  48.700
# 145     Botswana  Sub-Saharan Africa  3.467     9.782    0.784  59.269
# 146       Rwanda  Sub-Saharan Africa  3.415     7.676    0.552  61.400
# 147     Zimbabwe  Sub-Saharan Africa  3.145     7.943    0.750  56.201
# 148  Afghanistan          South Asia  2.523     7.695    0.463  52.493
#
#      Freedom  Generosity  Corruption
# 144    0.715      -0.131       0.915
# 145    0.824      -0.246       0.801
# 146    0.897       0.061       0.167
# 147    0.677      -0.047       0.821
# 148    0.382      -0.102       0.924

# %% [markdown]
# ### Happiness Score based on the Region

# %%
data = df.groupby('Region')[['Score']].sum()
data
# Out:
#                                       Score
# Region
# Central and Eastern Europe          101.741
# Commonwealth of Independent States   65.604
# East Asia                            34.862
# Latin America and Caribbean         118.161
# Middle East and North Africa         88.736
# North America and ANZ                28.514
# South Asia                           31.093
# Southeast Asia                       48.668
# Sub-Saharan Africa                  161.801
# Western Europe                      145.213

# %% [markdown]
# ### GDP vs Score

# %%
px.scatter(df, x='GDP(log)', y='Score',
           animation_frame='Region',
           animation_group='Country',
           color='Country', hover_name='Country',
           trendline= 'ols')
# Out:
# <div>                            <div id="777fca09-d74b-431a-891b-a53b0caeb581" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("777fca09-d74b-431a-891b-a53b0caeb581")) {                    Plotly.newPlot(                        "777fca09-d74b-431a-891b-a53b0caeb581",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Finland<br>Region=Western Europe<br>GDP(log)=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.775], "xaxis": "x", "y": [7.8420000000000005], "yaxis": "y"}, {"hovertemplate": "Country=Finland<br>Region=Western Europe<extra></extra>", "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Finland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Denmark<br>Region=Western Europe<br>GDP(log)=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Denmark"], "ids": ["Denmark"], "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Denmark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.933], "xaxis": "x", "y": [7.62], "yaxis": "y"}, {"hovertemplate": "Country=Denmark<br>Region=Western Europe<extra></extra>", "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Denmark", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Switzerland<br>Region=Western Europe<br>GDP(log)=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Switzerland"], "ids": ["Switzerland"], "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [11.117], "xaxis": "x", "y": [7.571000000000001], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Region=Western Europe<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines", "name": "Switzerland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Iceland<br>Region=Western Europe<br>GDP(log)=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Iceland"], "ids": ["Iceland"], "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.878], "xaxis": "x", "y": [7.553999999999999], "yaxis": "y"}, {"hovertemplate": "Country=Iceland<br>Region=Western Europe<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines", "name": "Iceland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Netherlands<br>Region=Western Europe<br>GDP(log)=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Netherlands"], "ids": ["Netherlands"], "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Netherlands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [10.932], "xaxis": "x", "y": [7.4639999999999995], "yaxis": "y"}, {"hovertemplate": "Country=Netherlands<br>Region=Western Europe<extra></extra>", "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "lines", "name": "Netherlands", "showlegend": false, "type": "scatter", "xaxis": "x", " ...

# %% [markdown]
# ### Support vs Score

# %%
px.scatter(df, x='Support', y='Score',
           animation_frame='Region',
           animation_group='Country',
           color='Country', hover_name='Country',
           trendline= 'ols')
# Out:
# <div>                            <div id="039691ae-7d46-41cd-af46-885f7091b2cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("039691ae-7d46-41cd-af46-885f7091b2cc")) {                    Plotly.newPlot(                        "039691ae-7d46-41cd-af46-885f7091b2cc",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Finland<br>Region=Western Europe<br>Support=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.9540000000000001], "xaxis": "x", "y": [7.8420000000000005], "yaxis": "y"}, {"hovertemplate": "Country=Finland<br>Region=Western Europe<extra></extra>", "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Finland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Denmark<br>Region=Western Europe<br>Support=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Denmark"], "ids": ["Denmark"], "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Denmark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.9540000000000001], "xaxis": "x", "y": [7.62], "yaxis": "y"}, {"hovertemplate": "Country=Denmark<br>Region=Western Europe<extra></extra>", "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Denmark", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Switzerland<br>Region=Western Europe<br>Support=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Switzerland"], "ids": ["Switzerland"], "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.9420000000000001], "xaxis": "x", "y": [7.571000000000001], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Region=Western Europe<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines", "name": "Switzerland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Iceland<br>Region=Western Europe<br>Support=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Iceland"], "ids": ["Iceland"], "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.983], "xaxis": "x", "y": [7.553999999999999], "yaxis": "y"}, {"hovertemplate": "Country=Iceland<br>Region=Western Europe<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines", "name": "Iceland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Netherlands<br>Region=Western Europe<br>Support=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Netherlands"], "ids": ["Netherlands"], "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Netherlands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.9420000000000001], "xaxis": "x", "y": [7.4639999999999995], "yaxis": "y"}, {"hovertemplate": "Country=Netherlands<br>Region=Western Europe<extra></extra>", "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "lines", "name": "Netherlands", "showlegend": ...

# %% [markdown]
# ### Health vs Score

# %%
px.scatter(df, x='Health', y='Score',
           animation_frame='Region',
           animation_group='Country',
           color='Country', hover_name='Country',
           trendline= 'ols')
# Out:
# <div>                            <div id="3392fdb5-4eaa-4ec6-9aa8-7d804da20e3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3392fdb5-4eaa-4ec6-9aa8-7d804da20e3f")) {                    Plotly.newPlot(                        "3392fdb5-4eaa-4ec6-9aa8-7d804da20e3f",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Finland<br>Region=Western Europe<br>Health=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [72.0], "xaxis": "x", "y": [7.8420000000000005], "yaxis": "y"}, {"hovertemplate": "Country=Finland<br>Region=Western Europe<extra></extra>", "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Finland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Denmark<br>Region=Western Europe<br>Health=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Denmark"], "ids": ["Denmark"], "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Denmark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [72.7], "xaxis": "x", "y": [7.62], "yaxis": "y"}, {"hovertemplate": "Country=Denmark<br>Region=Western Europe<extra></extra>", "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Denmark", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Switzerland<br>Region=Western Europe<br>Health=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Switzerland"], "ids": ["Switzerland"], "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [74.4], "xaxis": "x", "y": [7.571000000000001], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Region=Western Europe<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines", "name": "Switzerland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Iceland<br>Region=Western Europe<br>Health=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Iceland"], "ids": ["Iceland"], "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [73.0], "xaxis": "x", "y": [7.553999999999999], "yaxis": "y"}, {"hovertemplate": "Country=Iceland<br>Region=Western Europe<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines", "name": "Iceland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Netherlands<br>Region=Western Europe<br>Health=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Netherlands"], "ids": ["Netherlands"], "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Netherlands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [72.4], "xaxis": "x", "y": [7.4639999999999995], "yaxis": "y"}, {"hovertemplate": "Country=Netherlands<br>Region=Western Europe<extra></extra>", "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "lines", "name": "Netherlands", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hove ...

# %% [markdown]
# ### Freedom vs Score

# %%
px.scatter(df, x='Freedom', y='Score',
           animation_frame='Region',
           animation_group='Country',
           color='Country', hover_name='Country',
           trendline= 'ols')
# Out:
# <div>                            <div id="a77999fd-8958-4758-9c9b-8804015d169c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a77999fd-8958-4758-9c9b-8804015d169c")) {                    Plotly.newPlot(                        "a77999fd-8958-4758-9c9b-8804015d169c",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Finland<br>Region=Western Europe<br>Freedom=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.9490000000000001], "xaxis": "x", "y": [7.8420000000000005], "yaxis": "y"}, {"hovertemplate": "Country=Finland<br>Region=Western Europe<extra></extra>", "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Finland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Denmark<br>Region=Western Europe<br>Freedom=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Denmark"], "ids": ["Denmark"], "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Denmark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.946], "xaxis": "x", "y": [7.62], "yaxis": "y"}, {"hovertemplate": "Country=Denmark<br>Region=Western Europe<extra></extra>", "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Denmark", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Switzerland<br>Region=Western Europe<br>Freedom=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Switzerland"], "ids": ["Switzerland"], "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.919], "xaxis": "x", "y": [7.571000000000001], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Region=Western Europe<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines", "name": "Switzerland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Iceland<br>Region=Western Europe<br>Freedom=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Iceland"], "ids": ["Iceland"], "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.955], "xaxis": "x", "y": [7.553999999999999], "yaxis": "y"}, {"hovertemplate": "Country=Iceland<br>Region=Western Europe<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines", "name": "Iceland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Netherlands<br>Region=Western Europe<br>Freedom=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Netherlands"], "ids": ["Netherlands"], "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Netherlands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.9129999999999999], "xaxis": "x", "y": [7.4639999999999995], "yaxis": "y"}, {"hovertemplate": "Country=Netherlands<br>Region=Western Europe<extra></extra>", "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "lines", "name": "Netherlands", "showlegend": false, "type": "scatter", ...

# %% [markdown]
# ### Generosity vs Score

# %%
px.scatter(df, x='Generosity', y='Score',
           animation_frame='Region',
           animation_group='Country',
           color='Country', hover_name='Country',
           trendline= 'ols')
# Out:
# <div>                            <div id="ad91e925-2e48-40c8-94d3-cf228c5fd10e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad91e925-2e48-40c8-94d3-cf228c5fd10e")) {                    Plotly.newPlot(                        "ad91e925-2e48-40c8-94d3-cf228c5fd10e",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Finland<br>Region=Western Europe<br>Generosity=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [-0.098], "xaxis": "x", "y": [7.8420000000000005], "yaxis": "y"}, {"hovertemplate": "Country=Finland<br>Region=Western Europe<extra></extra>", "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Finland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Denmark<br>Region=Western Europe<br>Generosity=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Denmark"], "ids": ["Denmark"], "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Denmark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.03], "xaxis": "x", "y": [7.62], "yaxis": "y"}, {"hovertemplate": "Country=Denmark<br>Region=Western Europe<extra></extra>", "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Denmark", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Switzerland<br>Region=Western Europe<br>Generosity=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Switzerland"], "ids": ["Switzerland"], "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.025], "xaxis": "x", "y": [7.571000000000001], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Region=Western Europe<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines", "name": "Switzerland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Iceland<br>Region=Western Europe<br>Generosity=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Iceland"], "ids": ["Iceland"], "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.16], "xaxis": "x", "y": [7.553999999999999], "yaxis": "y"}, {"hovertemplate": "Country=Iceland<br>Region=Western Europe<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines", "name": "Iceland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Netherlands<br>Region=Western Europe<br>Generosity=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Netherlands"], "ids": ["Netherlands"], "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Netherlands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.175], "xaxis": "x", "y": [7.4639999999999995], "yaxis": "y"}, {"hovertemplate": "Country=Netherlands<br>Region=Western Europe<extra></extra>", "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "lines", "name": "Netherlands", "showlegend": false, "type": "scatter", "xaxis": "x ...

# %% [markdown]
# ### Corruption vs Score

# %%
px.scatter(df, x='Corruption', y='Score',
           animation_frame='Region',
           animation_group='Country',
           color='Country', hover_name='Country',
           trendline= 'ols')
# Out:
# <div>                            <div id="ac7bccbe-94eb-4820-97fc-ac1b91c3c29a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac7bccbe-94eb-4820-97fc-ac1b91c3c29a")) {                    Plotly.newPlot(                        "ac7bccbe-94eb-4820-97fc-ac1b91c3c29a",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Finland<br>Region=Western Europe<br>Corruption=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Finland"], "ids": ["Finland"], "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Finland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.18600000000000003], "xaxis": "x", "y": [7.8420000000000005], "yaxis": "y"}, {"hovertemplate": "Country=Finland<br>Region=Western Europe<extra></extra>", "legendgroup": "Finland", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "lines", "name": "Finland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Denmark<br>Region=Western Europe<br>Corruption=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Denmark"], "ids": ["Denmark"], "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Denmark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.179], "xaxis": "x", "y": [7.62], "yaxis": "y"}, {"hovertemplate": "Country=Denmark<br>Region=Western Europe<extra></extra>", "legendgroup": "Denmark", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "lines", "name": "Denmark", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Switzerland<br>Region=Western Europe<br>Corruption=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Switzerland"], "ids": ["Switzerland"], "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Switzerland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.292], "xaxis": "x", "y": [7.571000000000001], "yaxis": "y"}, {"hovertemplate": "Country=Switzerland<br>Region=Western Europe<extra></extra>", "legendgroup": "Switzerland", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "lines", "name": "Switzerland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Iceland<br>Region=Western Europe<br>Corruption=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Iceland"], "ids": ["Iceland"], "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Iceland", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.6729999999999999], "xaxis": "x", "y": [7.553999999999999], "yaxis": "y"}, {"hovertemplate": "Country=Iceland<br>Region=Western Europe<extra></extra>", "legendgroup": "Iceland", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "lines", "name": "Iceland", "showlegend": false, "type": "scatter", "xaxis": "x", "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>Country=Netherlands<br>Region=Western Europe<br>Corruption=%{x}<br>Score=%{y}<extra></extra>", "hovertext": ["Netherlands"], "ids": ["Netherlands"], "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Netherlands", "orientation": "v", "showlegend": true, "type": "scatter", "x": [0.33799999999999997], "xaxis": "x", "y": [7.4639999999999995], "yaxis": "y"}, {"hovertemplate": "Country=Netherlands<br>Region=Western Europe<extra></extra>", "legendgroup": "Netherlands", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "lines", "name": "Netherlands", "showlege ...

# %% [markdown]
# ### Seeing which feature is important to have high happiness score among top 10 countries

# %%
df.sort_values(by='Score',ascending=False).head(10).plot(x = 'Country',y=['Region','GDP(log)','Support','Health','Freedom','Generosity','Corruption'],kind='bar', figsize= (15, 15))
plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
# Out:
# Text(0.5, 1.0, 'Happiness Score of the top 10 Countries')

# %% [raw]
# It is clearly visible as the country where Health(Actually Healthy life expectancy) is high has a more happiness score. One more thing which is can be considered here is that the country where people take good care of their health in the current scenario of covid-19 the country's happiness score is high. The second most considerable feature is GDP.
